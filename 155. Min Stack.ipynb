# %% [markdown]
# # 155. Min Stack
#
# Design a stack that supports push, pop, top, and retrieving the minimum element in constant time.
#
# Implement the MinStack class:
#
# MinStack() initializes the stack object.
# void push(int val) pushes the element val onto the stack.
# void pop() removes the element on the top of the stack.
# int top() gets the top element of the stack.
# int getMin() retrieves the minimum element in the stack.
# You must implement a solution with O(1) time complexity for each function.
#
#
#
# Example 1:
#
# Input
# ["MinStack","push","push","push","getMin","pop","top","getMin"]
# [[],[-2],[0],[-3],[],[],[],[]]
#
# Output
# [null,null,null,null,-3,null,0,-2]
#
# Explanation
# MinStack minStack = new MinStack();
# minStack.push(-2);
# minStack.push(0);
# minStack.push(-3);
# minStack.getMin(); // return -3
# minStack.pop();
# minStack.top();    // return 0
# minStack.getMin(); // return -2
#
#
# Constraints:
#
# -231 <= val <= 231 - 1
# Methods pop, top and getMin operations will always be called on non-empty stacks.
# At most 3 * 104 calls will be made to push, pop, top, and getMin.

# %%
class MinStack:

    def __init__(self):
        # creating a list to instantiate min stack object
        self.min_stack = []
        self.min_val_stack = []
        # self.min_val_history = None

    def push(self, val: int) -> None:
        ## push the element
        self.min_stack.append(val)

        ## check if the added element is the minimum value upto now.
        if self.min_stack:
            if val < self.min_stack[-1]:
                self.min_val_stack.append(val)
        else:
            self.min_val_stack.append(val)

    def pop(self) -> None:
        if self.min_stack[-1] == self.min_val_stack[-1]:
            ## remove the last element
            self.min_stack.pop()
            self.min_val_stack.pop()
        else:
            ## remove the last element
            self.min_stack.pop()

    def top(self) -> int:
        ## returning last element
        return self.min_stack[-1]

    def getMin(self) -> int:
        ## returning the min value
        return self.min_val_stack[-1]


# Your MinStack object will be instantiated and called as such:
# obj = MinStack()
# obj.push(val)
# obj.pop()
# param_3 = obj.top()
# param_4 = obj.getMin()

# %%
["MinStack","push","push","push","top","pop","getMin","pop","getMin","pop","push","top","getMin","push","top","getMin","pop","getMin"]
